# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array = np.array([1,2,3])
array2 = np.array([6,1,33])
print(f"array: {array} \narray.shape: {array.shape}")
# Out:
# array: [1 2 3]
# array.shape: (3,)

# %%
array_2d = np.array([[1,2,3], [3,4,5]])
print(f"array:\n{array_2d} \narray.shape: {array_2d.shape}")
# Out:
# array:
# [[1 2 3]
#  [3 4 5]]
# array.shape: (2, 3)

# %%
len(array)
# Out:
# 3

# %%
len(array_2d)
# Out:
# 2

# %%
len(array_2d.T)
# Out:
# 3

# %%
plt.scatter(array, array, marker = 'o', c='b')

# %%
plt.scatter(array_2d, array_2d.T, marker = 'x', c='r')
